# %%
from os import listdir
from os.path import isfile, join
import json
import seaborn as sns
import pandas as pd

# %%
def process_json(json):
    if json["input"]["consensus"] != "HotStuff":
        json["input"]["consensus"] = "Jasmine"
    cate = json["input"]["consensus"] + str(json["input"]["node_settings"]["batch_size"]) + str(json["input"]["node_settings"]["transaction_size"]) + \
       str(json["input"]["node_settings"]["leader_rotation"])
    row = {
        "cate": [cate],
        "consensus-latency":[json["output"]["average_delay"]],
        "rate" : json["input"]["client"]["injection_rate"],
        "latency": [json["output"]["e2e_delay"]],
        "throughput": [json["output"]["consensus_throughput"]],
    }
    return pd.DataFrame(row)

# %%
mypath = "./1-plan"
fs = [f for f in listdir(mypath) if isfile(join(mypath, f))]
fs = [join(mypath, f) for f in fs if f.startswith('result')]
fs
df = pd.DataFrame()

for f in fs:
    with open(f) as file:
        data = json.load(file)
    r = process_json(data)
    df = pd.concat([df, r])

df = df.sort_values(by=["cate", "rate"])
df
# Out:
#                  cate  consensus-latency     rate     latency   throughput
# 0  HotStuff1000512100           1.399499      200   69.648436     0.799000
# 0  HotStuff1000512100           1.444305     1000   68.058798     3.995000
# 0  HotStuff1000512100           1.560301     3000   69.534470    11.970000
# 0  HotStuff1000512100           1.572742     4000   72.294511    15.940000
# 0  HotStuff1000512100           1.829137     9000   65.668250    35.865000
# 0  HotStuff1000512100           1.793089    10000   61.889857    39.950000
# 0  HotStuff1000512100           2.180610    30000   53.904069   119.571429
# 0  HotStuff1000512100           2.418280    40000   50.716231   159.454545
# 0  HotStuff1000512100           2.689711    80000   58.475384   319.040000
# 0  HotStuff1000512100           2.733763    90000   63.431393   358.961538
# 0  HotStuff1000512100           2.877724   120000   71.375567   478.800000
# 0  HotStuff1000512100           3.041548   190000   93.247106   756.200000
# 0  HotStuff1000512100           3.162540   220000  112.793784   874.808346
# 0  HotStuff1000512100           3.576363   250000  184.954807   982.333333
# 0  HotStuff1000512100           3.584507   260000  203.331843   984.675333
# 0  HotStuff1000512100           3.580173   270000  203.096643   987.474182
# 0  HotStuff1000512100           3.574114   280000  203.415299   989.035664
# 0  HotStuff1000512100           3.526964   300000  201.838252  1003.866667
# 0  HotStuff1000512100           3.584800   320000  203.958392   991.266667
# 0  HotStuff1000512100           3.569733   330000  203.979319   994.533333
# 0  HotStuff1000512100           3.565991   340000  204.270832   994.000000
# 0  HotStuff1000512100           3.560018   350000  204.780206   989.821037
# 0  HotStuff1000512100           3.585651   390000  205.197632   991.933333
# 0  HotStuff1000512100           3.562879   400000  203.828767   996.867293
# 0  HotStuff1000512100           3.511863   500000  201.839275  1009.917200
# 0  HotStuff1000512100           3.543507  1000000  203.139106  1005.273333
# 0  HotStuff1000512100           3.528102  2000000  204.113044  1002.948000
# 0  HotStuff1000512100           3.563718  4000000  204.400556   999.008667
# 0  HotStuff1000512100           3.580786  9000000  206.294462   992.208667
# 0   Jasmine1000512100           1.613423     4000   72.808473    15.980000
# 0   Jasmine1000512100           1.823158    10000   62.073296    39.900000
# 0   Jasmine1000512100           2.363027    20000   48.605919    79.714286
# 0   Jasmine1000512100           2.852384    40000   51.774521   159.545455
# 0   Jasmine1000512100           3.649058    80000   55.711497   319.040000
# 0   Jasmine1000512100           4.037744   100000   57.855432   398.750000
# 0   Jasmine1000512100           5.451284   200000   83.677108   798.000000
# 0   Jasmine1000512100           5.664128   400000  103.633910  1579.000000
# 0   Jasmine1000512100           6.084364   800000  106.454862  1854.310467
# 0   Jasmine1000512100           6.136781  1000000   99.571018  1941.390267
# 0   Jasmine1000512100           6.050609  3000000  100.724813  1927.947133
# 0   Jasmine1000512100           5.901086  5000000   95.380671  2001.226385
# 0   Jasmine1000512100           6.028905  9000000  105.709264  1868.250583

# %%
# Plot the lines on two facets
# Define the palette as a list to specify exact values

sns.lineplot(
    data=df,
    x="throughput", y="latency",sort=False,
    hue="cate",
)
# Out:
# <AxesSubplot:xlabel='throughput', ylabel='latency'>
